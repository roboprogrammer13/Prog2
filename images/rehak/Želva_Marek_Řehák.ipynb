# %% [markdown]
# <a href="https://colab.research.google.com/github/MarekRehak/-eh-k/blob/main/%C5%BDelva_Marek_%C5%98eh%C3%A1k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=10,initial_window_size=(500,200))
# Out:
#       <svg width="500" height="200">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,250,100) translate(232, 82)">
# ...

# %%
# !pip install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7643 sha256=ec79b621d1384451c51edd35c77fc6f238fd36064e0fd5c08b42e176b9d5427b
#   Stored in directory: /root/.cache/pip/wheels/9f/af/64/ffd85f9858ed7d56b7293dcedbc9d461bf13c8cfc97e352bc8
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *
initializeTurtle()

color('orange')
width(3)

for _ in range(4):
    forward(150)
    left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="400.0" y1="100.0" x2="250.0" y2="100.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="250.0" y1="100.0" x2="250.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="250.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
from ColabTurtle.Turtle import *
initializeTurtle()

color('orange')
width(3)

for _ in range(6):
    forward(100)
    left(60)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="400.0" y1="150.0" x2="313.397" y2="100.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="313.397" y1="100.0" x2="226.794" y2="150.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="226.794" y1="150.0" x2="226.794" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="226.794" y1="250.0" x2="313.397" y2="300.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/><line x1="313.397" y1="300.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:orange;stroke-width:3"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=13, initial_window_size=(600, 400))
bgcolor('black') # Dark background for a vibrant spiral
speed(10) # Fast drawing speed

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple']
width(2)

for i in range(200):
    pencolor(colors[i % 6]) # Cycle through colors
    forward(i)             # Each line segment gets longer
    left(59)               # Turn slightly less than 60 degrees to create a spiral effect
# Out:
#       <svg width="600" height="400">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=13, initial_window_size=(600, 400))
bgcolor('midnightblue') # Dark background for good contrast
speed(10) # Max speed

colors = ['red', 'orange', 'yellow', 'lime', 'cyan', 'magenta'] # More colors for variety
width(3) # Slightly thicker lines

penup()
setposition(300, 200) # Start in the center
pendown()

for i in range(150):
    pencolor(colors[i % 6]) # Cycle through colors
    forward(i * 2)         # Each line segment gets significantly longer
    left(144)              # Turn 144 degrees to create a 5-pointed star pattern (360/5 * 2)
# Out:
#       <svg width="600" height="400">
#         <rect width="100%" height="100%" fill="midnightblue"/>
# ...

# %% [markdown]
# ### Colorful Floral Pattern
#
# This code generates a mesmerizing floral pattern using `ColabTurtle`. It sets a dark background and cycles through a list of colors. The pattern is created by repeatedly drawing lines of increasing length and turning at precise angles, which leads to a complex and beautiful symmetrical design.

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=13, initial_window_size=(700, 700))
bgcolor('darkslategrey') # A calming dark background
speed(10) # Set a good drawing speed

colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#9400D3'] # Rainbow colors
width(2) # Slightly thicker lines for visibility

penup()
setposition(350, 350) # Start in the center of the window
pendown()

for i in range(360): # Loop many times to create a dense pattern
    pencolor(colors[i % len(colors)]) # Cycle through the rainbow colors
    forward(i * 0.8) # Increase line length gradually for a spiral effect
    left(135) # A specific turn angle to create petal-like shapes (e.g., 135, 144, 150 can make interesting patterns)
# Out:
#       <svg width="700" height="700">
#         <rect width="100%" height="100%" fill="darkslategrey"/>
# ...

# %% [markdown]
# ### Koncentrické rotující čtverce
#
# Tento kód vytváří dynamický vzor koncentrických čtverců, které se postupně zvětšují a mírně rotují. Každý čtverec je nakreslen jinou barvou z definovaného seznamu. Nastavení `darkblue` pozadí pomáhá kontrastu s jasnými barvami čtverců, vytváří zajímavý vizuální efekt, který se liší od spirál a hvězd.

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=13, initial_window_size=(600, 600))
bgcolor('darkblue') # Tmavě modré pozadí pro výrazný kontrast
speed(10) # Maximální rychlost kreslení

colors = ['cyan', 'lime', 'yellow', 'orange', 'red', 'magenta'] # Sada jasných barev
width(2) # Střední tloušťka čáry

penup()
setposition(300, 300) # Začínáme v přesném středu okna
pendown()

side_length = 10 # Počáteční délka strany čtverce
angle_increment = 5 # Úhel rotace pro každý další čtverec
num_squares = 60 # Počet čtverců, které se nakreslí

for i in range(num_squares):
    pencolor(colors[i % len(colors)]) # Cyklická změna barvy pro každý čtverec
    # Nakreslete jeden čtverec
    for _ in range(4):
        forward(side_length)
        left(90)
    left(angle_increment) # Mírně otočte želvu pro další čtverec
    side_length += 5      # Zvětšete délku strany pro další čtverec, aby se rozšiřoval ven
# Out:
#       <svg width="600" height="600">
#         <rect width="100%" height="100%" fill="darkblue"/>
# ...

# %% [markdown]
# ### Dynamická organická spirála
#
# Tento kód generuje unikátní organickou spirálu. Na tmavém pozadí se želva pohybuje vpřed a její délka kroku se postupně zvětšuje. Klíčovým prvkem je, že úhel otočení se s každým krokem mírně mění, což vytváří nepravidelnou a dynamickou spirálu namísto geometricky přesného tvaru. Barvy se cyklicky mění, což přidává vizuální komplexnost.

# %%
from ColabTurtle.Turtle import *

initializeTurtle(initial_speed=13, initial_window_size=(700, 700))
bgcolor('darkslateblue') # Tmavé modrofialové pozadí
speed(10) # Maximální rychlost kreslení

colors = ['gold', 'red', 'lightgreen', 'deepskyblue', 'magenta', 'orange'] # Nová sada živých barev
width(2)

penup()
setposition(350, 350) # Začínáme uprostřed okna
pendown()

for i in range(300): # Hodně iterací pro hustotu vzoru
    pencolor(colors[i % len(colors)]) # Cyklická změna barev
    forward(i * 0.7) # Délka čáry se postupně zvyšuje
    left(i / 10 + 90) # Úhel se mění s každou iterací, vytváří dynamickou spirálu
# Out:
#       <svg width="700" height="700">
#         <rect width="100%" height="100%" fill="darkslateblue"/>
# ...

# %% [markdown]
# ### Kompozice: Dynamická spirála a rotující čtverce
#
# Tento kód vytváří komplexní obrazec, který kombinuje několik různých prvků na jednom plátně. Uprostřed je dynamická, organicky se vyvíjející spirála s měnícím se úhlem otáčení a barvami. V každém ze čtyř rohů jsou pak menší sady koncentrických rotujících čtverců, každý s vlastní barevnou paletou. Pozadí je tmavé pro zvýraznění všech živých barev.

# %%
from ColabTurtle.Turtle import *
import random

initializeTurtle(initial_speed=13, initial_window_size=(800, 800)) # Větší plátno
bgcolor('darkslategrey') # Tmavé, ale ne černé pozadí
speed(10)

# --- Funkce pro kreslení dynamické spirály ---
def draw_dynamic_spiral(x, y, num_iterations, base_length, angle_modifier, colors):
    penup()
    setposition(x, y)
    pendown()
    for i in range(num_iterations):
        pencolor(colors[i % len(colors)])
        forward(base_length + i * 0.7)
        left(i / angle_modifier + 90)

# --- Funkce pro kreslení koncentrických rotujících čtverců ---
def draw_rotating_squares(x, y, num_squares, start_side_length, angle_increment, size_increment, colors):
    penup()
    setposition(x, y)
    pendown()
    current_side_length = start_side_length
    for i in range(num_squares):
        pencolor(colors[i % len(colors)])
        for _ in range(4):
            forward(current_side_length)
            left(90)
        left(angle_increment)
        current_side_length += size_increment

# --- Funkce pro kreslení paprsků (sunburst) ---
def draw_sunburst(x, y, num_rays, ray_length, colors):
    penup()
    setposition(x, y)
    pendown()
    setheading(0) # Začínáme s želvou směřující na východ
    angle_step = 360 / num_rays
    for i in range(num_rays):
        pencolor(colors[i % len(colors)])
        forward(ray_length)
        backward(ray_length) # Vrátíme se do středu
        left(angle_step)

# --- Nová funkce pro kreslení radiálních záblesků v kvadrantech ---
def draw_radial_burst(x, y, num_lines, line_length, colors):
    penup()
    setposition(x, y)
    pendown()
    original_heading = heading() # Uložíme původní směr
    angle_step = 360 / num_lines
    for i in range(num_lines):
        pencolor(colors[i % len(colors)])
        forward(line_length)
        backward(line_length)
        left(angle_step)
    setheading(original_heading) # Obnovíme původní směr

# --- Nová funkce pro spojení bodů čárami do čtverce ---
def draw_connecting_square(point1, point2, point3, point4, color, line_width):
    penup()
    setposition(point1[0], point1[1])
    pendown()
    pencolor(color)
    width(line_width)
    setposition(point2[0], point2[1])
    setposition(point3[0], point3[1])
    setposition(point4[0], point4[1])
    setposition(point1[0], point1[1]) # Zpět na začátek pro uzavření čtverce

# --- Nová funkce pro kreslení rozšiřujících se hvězd (pro konkrétní efekty) ---
def draw_expanding_stars(x, y, num_stars, num_points, start_size, size_increment, angle_increment, colors):
    penup()
    setposition(x, y)
    pendown()
    current_size = start_size
    for i in range(num_stars):
        pencolor(colors[i % len(colors)])
        for _ in range(num_points):
            forward(current_size)
            right(360 / num_points * 2) # Pro 5cípou hvězdu je to 144 stupňů (360/5 * 2)
            forward(current_size)
            left(360 / num_points) # Aby se vrátil do výchozího směru pro další rameno
        left(angle_increment) # Rotace celé hvězdy
        current_size += size_increment # Zvětšení velikosti

# --- Nová funkce pro kreslení jedné statické hvězdy ---
def draw_static_single_star(x, y, size, num_points, color):
    penup()
    setposition(x, y)
    pencolor(color)
    width(1)
    pendown()
    for _ in range(num_points):
        forward(size)
        right(360 / num_points * 2)
        forward(size)
        left(360 / num_points)
    penup()

# --- Nová funkce pro kreslení malé, husté spirály ---
def draw_small_spiral_corner(x, y, num_iterations, initial_length, angle, colors, pen_thickness):
    penup()
    setposition(x, y)
    pendown()
    width(pen_thickness)
    for i in range(num_iterations):
        pencolor(colors[i % len(colors)])
        forward(initial_length + i * 0.5)
        left(angle)

# --- Nová funkce pro kreslení malých polygonových 'květin' ---
def draw_small_polygon_flower(x, y, size, num_sides, rotation_angle, colors, line_width):
    penup()
    setposition(x, y)
    pendown()
    pencolor(random.choice(colors))
    width(line_width)
    setheading(random.randint(0, 359)) # Náhodný počáteční směr
    left(rotation_angle) # Počáteční rotace
    for _ in range(num_sides):
        forward(size)
        left(360 / num_sides)
    penup()

# --- Hlavní kompozice ---

# 1. Centrální dynamická spirála
spiral_colors = ['gold', 'red', 'lightgreen', 'deepskyblue', 'magenta', 'orange']
draw_dynamic_spiral(400, 400, 200, 0, 10, spiral_colors)

# 2. Rotující čtverce v rozích
square_colors_1 = ['cyan', 'skyblue', 'blue', 'darkblue']
draw_rotating_squares(150, 150, 20, 5, 10, 3, square_colors_1) # Levý horní

square_colors_2 = ['lime', 'green', 'darkgreen', 'forestgreen']
draw_rotating_squares(650, 150, 20, 5, 10, 3, square_colors_2) # Pravý horní

square_colors_3 = ['yellow', 'orange', 'darkorange', 'chocolate']
draw_rotating_squares(150, 650, 20, 5, 10, 3, square_colors_3) # Levý dolní

square_colors_4 = ['magenta', 'purple', 'darkviolet', 'indigo']
draw_rotating_squares(650, 650, 20, 5, 10, 3, square_colors_4) # Pravý dolní

# 3. Přidáme Sunburst efekty do středu každé strany
sunburst_colors = ['white', 'silver', 'grey']
draw_sunburst(400, 100, 15, 50, sunburst_colors) # Horní střed
draw_sunburst(400, 700, 15, 50, sunburst_colors) # Dolní střed
draw_sunburst(100, 400, 15, 50, sunburst_colors) # Levý střed
draw_sunburst(700, 400, 15, 50, sunburst_colors) # Pravý střed

# 4. Přidáme radiální záblesky do kvadrantů
radial_colors = ['lightblue', 'lightcoral', 'lightgreen', 'lavender']
draw_radial_burst(275, 275, 12, 40, radial_colors) # Levý horní kvadrant
draw_radial_burst(525, 275, 12, 40, radial_colors) # Pravý horní kvadrant
draw_radial_burst(275, 525, 12, 40, radial_colors) # Levý dolní kvadrant
draw_radial_burst(525, 525, 12, 40, radial_colors) # Pravý dolní kvadrant

# 5. Spojíme středy radiálních záblesků čárami do čtverce
connect_color = 'white'
connect_width = 2

point_lh = (275, 275) # Levý horní
point_ph = (525, 275) # Pravý horní
point_ld = (275, 525) # Levý dolní
point_pd = (525, 525) # Pravý dolní

draw_connecting_square(point_lh, point_ph, point_pd, point_ld, connect_color, connect_width)

# 6. Přidáme rozšiřující se hvězdy do zbývajících rohů (původní použití)
star_colors_expanding = ['gold', 'red', 'lightgreen', 'blue', 'magenta']
draw_expanding_stars(200, 200, 10, 5, 10, 5, 15, star_colors_expanding) # Mezi levým horním čtvercem a sunburstem
draw_expanding_stars(600, 200, 10, 5, 10, 5, 15, star_colors_expanding) # Mezi pravým horním čtvercem a sunburstem

# 7. Přidáme malé statické hvězdičky po celém obrázku k vyplnění prázdných míst
small_star_colors = ['white', 'yellow', 'lightblue', 'pink']
num_small_stars = 100
for _ in range(num_small_stars):
    star_x = random.randint(50, 750)
    star_y = random.randint(50, 750)
    star_size = random.randint(5, 15)
    star_points = random.choice([4, 5, 6]) # Různé počty cípů
    star_color = random.choice(small_star_colors)
    draw_static_single_star(star_x, star_y, star_size, star_points, star_color)

# 8. Přidáme malé husté spirály do úplných rohů plátna
corner_spiral_colors = ['white', 'silver', 'cyan', 'magenta']
draw_small_spiral_corner(50, 50, 50, 1, 89, corner_spiral_colors, 1)    # Levý horní
draw_small_spiral_corner(750, 50, 50, 1, 89, corner_spiral_colors, 1)  # Pravý horní
draw_small_spiral_corner(50, 750, 50, 1, 89, corner_spiral_colors, 1)  # Levý dolní
draw_small_spiral_corner(750, 750, 50, 1, 89, corner_spiral_colors, 1) # Pravý dolní

# 9. Přidáme malé polygonové 'květiny' po celém plátně pro vyplnění mezer
flower_colors = ['#FFC0CB', '#DA70D6', '#BA55D3', '#9370DB', '#8A2BE2', '#4B0082'] # Odstíny růžové a fialové
num_flowers = 80
for _ in range(num_flowers):
    flower_x = random.randint(20, 780)
    flower_y = random.randint(20, 780)
    flower_size = random.randint(5, 20)
    flower_sides = random.choice([3, 4, 5, 6]) # Trojúhelníky, čtverce, pětiúhelníky, šestiúhelníky
    flower_rotation = random.randint(0, 90)
    draw_small_polygon_flower(flower_x, flower_y, flower_size, flower_sides, flower_rotation, flower_colors, 1)
# Out:
#       <svg width="800" height="800">
#         <rect width="100%" height="100%" fill="darkslategrey"/>
# ...

# %% [markdown]
# # Task
# Draw an intricate mandala using ColabTurtle. The drawing should feature a large canvas (1200x900) with a black background and a subtle texture composed of many thin, randomly placed short lines in dark colors. The mandala itself should be prominent, incorporating concentric patterns, rotational symmetry, and a vibrant color palette to stand out against the background.

# %% [markdown]
# ## Initialize Canvas
#
# ### Subtask:
# Initialize ColabTurtle with a large window size (1200x900) and set the background color to black with maximum speed.

# %% [markdown]
# **Reasoning**:
# To initialize ColabTurtle as per the subtask instructions, I need to import the necessary function and call it with the specified parameters for window size, background color, and speed.

# %%
from ColabTurtle.Turtle import initializeTurtle, bgcolor

initializeTurtle(initial_window_size=(1200, 900), initial_speed=13)
bgcolor('black')
speed(13)
# Out:
#       <svg width="1200" height="900">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,600,450) translate(582, 432)">
# ...

# %% [markdown]
# ## Draw Dark Line Texture
#
# ### Subtask:
# Create a function that draws many thin, randomly placed short lines across the entire canvas using a palette of dark colors (dark yellow, dark red, etc.) to form a subtle background texture.

# %% [markdown]
# **Reasoning**:
# I need to define a Python function `draw_dark_texture` that generates a subtle background texture using randomly placed short lines of dark colors, as specified in the instructions. This function will be called after canvas initialization.

# %%
from ColabTurtle.Turtle import initializeTurtle, bgcolor, penup, setposition, pendown, pencolor, forward, width, setheading
import random

# Initialize ColabTurtle with a large window size (1200x900) and set the background color to black with maximum speed.
initializeTurtle(initial_window_size=(1200, 900), initial_speed=13)
bgcolor('black')
speed(13)

def draw_dark_texture(canvas_width, canvas_height, num_lines):
    dark_colors = ['darkgray', 'darkslategray', 'saddlebrown', 'darkgreen', 'indigo', 'darkred', 'darkgoldenrod', 'darkslateblue']
    width(1) # Set pen width to a small value

    # Hide the turtle for faster drawing of the background texture
    penup()
    hideturtle()

    for _ in range(num_lines):
        # Generate random coordinates within the canvas
        x = random.randint(0, canvas_width)
        y = random.randint(0, canvas_height)
        setposition(x, y)

        # Set a random dark color
        pencolor(random.choice(dark_colors))

        pendown()

        # Generate a random length for the line (between 5 and 20 units)
        line_length = random.randint(5, 20)

        # Generate a random angle for the line's direction
        random_angle = random.randint(0, 359)
        setheading(random_angle)

        # Draw the short line
        forward(line_length)

        penup() # Lift pen after drawing each line
    showturtle() # Show turtle again for subsequent main mandala drawing

# Call the function to draw the dark line texture
# Canvas dimensions are 1200x900, let's draw a good number of lines for subtle texture
draw_dark_texture(1200, 900, 200) # Draw 1500 short lines
# Out:
#       <svg width="1200" height="900">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# ## Draw Mandala Function
#
# ### Subtask:
# Define a flexible function to draw large, intricate mandalas at specified coordinates, incorporating concentric patterns, rotational symmetry, and a vibrant color palette to contrast with the dark background.

# %% [markdown]
# **Reasoning**:
# I need to define the `draw_mandala` function according to the instructions, incorporating parameters for position, size, rotational symmetry, concentric patterns, and a vibrant color palette. This function will be added to the existing `ColabTurtle` script.

# %%
from ColabTurtle.Turtle import initializeTurtle, bgcolor, penup, setposition, pendown, pencolor, forward, width, setheading, left, right, hideturtle, showturtle
import random

# Re-initialize ColabTurtle as the previous cell's state might be lost in execution sequence
# Or, if this is meant to be a new cell, it should be self-contained.
# Assuming this is a new cell that builds upon the initialized canvas and texture drawing.
initializeTurtle(initial_window_size=(1200, 900), initial_speed=13)
bgcolor('black')

# Definition for draw_dark_texture function, copied from previous successful step
def draw_dark_texture(canvas_width, canvas_height, num_lines):
    dark_colors = ['darkgray', 'darkslategray', 'saddlebrown', 'darkgreen', 'indigo', 'darkred', 'darkgoldenrod', 'darkslateblue']
    width(1)

    penup()
    hideturtle()

    for _ in range(num_lines):
        x = random.randint(0, canvas_width)
        y = random.randint(0, canvas_height)
        setposition(x, y)
        pencolor(random.choice(dark_colors))
        pendown()
        line_length = random.randint(5, 20)
        random_angle = random.randint(0, 359)
        setheading(random_angle)
        forward(line_length)
        penup()
    showturtle()

# Call the function to draw the dark line texture as a prerequisite
draw_dark_texture(1200, 900, 500)

# Define the draw_mandala function
def draw_mandala(x, y, size, num_segments, colors):
    penup()
    setposition(x, y)
    pendown()
    hideturtle()
    speed(10) # Ensure maximum speed for drawing the mandala

    segment_angle = 360 / num_segments
    initial_heading = 0 # Start facing right
    setheading(initial_heading)

    for i in range(num_segments):
        pencolor(colors[i % len(colors)]) # Cycle through vibrant colors
        width(size / 30) # Adjust pen width based on overall mandala size

        # --- Draw a 'petal' or segment --- START
        # Move to the starting point of the petal from the center
        penup()
        setposition(x,y)
        setheading(initial_heading + i * segment_angle) # Orient for this segment
        forward(size * 0.1) # Move out a bit from the center
        pendown()

        # Nested loop for concentric pattern within each segment
        for j in range(int(size * 0.5)):
            pencolor(colors[(i + j) % len(colors)])
            width(max(1, int((size / 30) - (j / (size * 0.5) * (size / 30))))) # Decrease width for concentric effect
            forward(size * 0.05 + j * 0.005) # Gradually increase forward length
            left(10) # Small turn for a spiral within the petal
            forward(size * 0.05 + j * 0.005) # Another forward
            right(11) # Turn back slightly

        # Additional concentric layer / outline for the petal
        penup()
        setposition(x,y)
        setheading(initial_heading + i * segment_angle + segment_angle/2) # Move to middle of the segment
        forward(size * 0.05) # Start a bit out
        pendown()
        pencolor(colors[(i + 1) % len(colors)])
        width(max(1, int(size / 50))) # Thinner line for outline
        for k in range(int(size / 4)):
            forward(size * 0.002)
            right(1.5)
        for k in range(int(size / 4)):
            forward(size * 0.002)
            left(1.5)
        # --- Draw a 'petal' or segment --- END

        penup()
        setposition(x, y) # Return to center for the next segment
        pendown()
    showturtle() # Show turtle again after drawing the mandala
# Out:
#       <svg width="1200" height="900">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
from ColabTurtle.Turtle import initializeTurtle, bgcolor, penup, setposition, pendown, pencolor, forward, width, setheading, left, right, hideturtle, showturtle, speed
import random

# Initialize ColabTurtle with a large window size (1200x900) and set the background color to black with maximum speed.
initializeTurtle(initial_window_size=(1200, 900), initial_speed=13)
bgcolor('black')
speed(13)

def draw_dark_texture(canvas_width, canvas_height, num_lines):
    dark_colors = ['darkgray', 'darkslategray', 'saddlebrown', 'darkgreen', 'indigo', 'darkred', 'darkgoldenrod', 'darkslateblue']
    width(1) # Set pen width to a small value

    # Hide the turtle for faster drawing of the background texture
    penup()
    hideturtle()

    for _ in range(num_lines):
        # Generate random coordinates within the canvas
        x = random.randint(0, canvas_width)
        y = random.randint(0, canvas_height)
        setposition(x, y)

        # Set a random dark color
        pencolor(random.choice(dark_colors))

        pendown()

        # Generate a random length for the line (between 5 and 20 units)
        line_length = random.randint(5, 20)

        # Generate a random angle for the line's direction
        random_angle = random.randint(0, 359)
        setheading(random_angle)

        # Draw the short line
        forward(line_length)

        penup() # Lift pen after drawing each line
    showturtle() # Show turtle again for subsequent main mandala drawing

# Call the function to draw the dark line texture as a prerequisite
draw_dark_texture(1200, 900, 500) # Draw 500 short lines for a subtle texture

# Define the draw_mandala function
def draw_mandala(x, y, size, num_segments, colors):
    penup()
    setposition(x, y)
    pendown()
    hideturtle()
    speed(10) # Ensure maximum speed for drawing the mandala

    segment_angle = 360 / num_segments
    initial_heading = 0 # Start facing right
    setheading(initial_heading)

    for i in range(num_segments):
        pencolor(colors[i % len(colors)]) # Cycle through vibrant colors
        width(int(size / 50) + 1) # Corrected: Ensure width is an integer, add 1 to avoid zero width

        # --- Draw a 'petal' or segment --- START
        # Move to the starting point of the petal from the center
        penup()
        setposition(x,y)
        setheading(initial_heading + i * segment_angle) # Orient for this segment
        forward(size * 0.1) # Move out a bit from the center
        pendown()

        # Nested loop for concentric pattern within each segment
        # Halved iterations for faster drawing
        for j in range(int(size * 0.1)):
            pencolor(colors[(i + j) % len(colors)])
            current_width = max(1, int((size / 50) - (j / (size * 0.1) * (size / 50)) + 1)) # Decrease width for concentric effect
            width(current_width)
            forward(size * 0.05 + j * 0.005) # Gradually increase forward length
            left(10) # Small turn for a spiral within the petal
            forward(size * 0.05 + j * 0.005) # Another forward
            right(11) # Turn back slightly

        # Additional concentric layer / outline for the petal
        penup()
        setposition(x,y)
        setheading(initial_heading + i * segment_angle + segment_angle/2) # Move to middle of the segment
        forward(size * 0.15) # Start a bit out for the outline
        pendown()
        pencolor(colors[(i + 1) % len(colors)])
        width(max(1, int(size / 70))) # Corrected: Ensure width is an integer
        # Halved iterations for faster drawing
        for k in range(int(size / 16)):
            forward(size * 0.003)
            right(2)
        for k in range(int(size / 16)):
            forward(size * 0.003)
            left(2)
        # --- Draw a 'petal' or segment --- END

        penup()
        setposition(x, y) # Return to center for the next segment
        pendown()
    showturtle() # Show turtle again after drawing the mandala

# Define vibrant colors for the mandala
mandala_colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#9400D3', '#FF1493', '#00FFFF']

# Draw the main intricate mandala in the center with reduced segments for faster drawing
draw_mandala(600, 450, 450, 18, mandala_colors)
# Out:
#       <svg width="1200" height="900">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# **Reasoning**:
# The `NameError` for 'speed' occurred because it was not explicitly imported from `ColabTurtle.Turtle`. I have added `speed` to the import list. Additionally, to prevent future `ValueError`s from floating-point arguments passed to `width()`, I will ensure all calculations for line width are explicitly cast to integers using `int()`. I've also re-checked the iterations for the drawing functions to ensure they are reasonable.

# %%
from ColabTurtle.Turtle import initializeTurtle, bgcolor, penup, setposition, pendown, pencolor, forward, width, setheading, left, right, hideturtle, showturtle, speed
import random

# Initialize ColabTurtle with a large window size (1200x900) and set the background color to black with maximum speed.
initializeTurtle(initial_window_size=(1200, 900), initial_speed=13)
bgcolor('black')
speed(13)

def draw_dark_texture(canvas_width, canvas_height, num_lines):
    dark_colors = ['darkgray', 'darkslategray', 'saddlebrown', 'darkgreen', 'indigo', 'darkred', 'darkgoldenrod', 'darkslateblue']
    width(1) # Set pen width to a small value

    # Hide the turtle for faster drawing of the background texture
    penup()
    hideturtle()

    for _ in range(num_lines):
        # Generate random coordinates within the canvas
        x = random.randint(0, canvas_width)
        y = random.randint(0, canvas_height)
        setposition(x, y)

        # Set a random dark color
        pencolor(random.choice(dark_colors))

        pendown()

        # Generate a random length for the line (between 5 and 20 units)
        line_length = random.randint(5, 20)

        # Generate a random angle for the line's direction
        random_angle = random.randint(0, 359)
        setheading(random_angle)

        # Draw the short line
        forward(line_length)

        penup() # Lift pen after drawing each line
    showturtle() # Show turtle again for subsequent main mandala drawing

# Call the function to draw the dark line texture as a prerequisite
draw_dark_texture(1200, 900, 500) # Draw 500 short lines for a subtle texture

# Define the draw_mandala function
def draw_mandala(x, y, size, num_segments, colors):
    penup()
    setposition(x, y)
    pendown()
    hideturtle()
    speed(10) # Ensure maximum speed for drawing the mandala

    segment_angle = 360 / num_segments
    initial_heading = 0 # Start facing right
    setheading(initial_heading)

    for i in range(num_segments):
        pencolor(colors[i % len(colors)]) # Cycle through vibrant colors
        width(int(size / 50) + 1) # Ensure width is an integer

        # --- Draw a 'petal' or segment --- START
        # Move to the starting point of the petal from the center
        penup()
        setposition(x,y)
        setheading(initial_heading + i * segment_angle) # Orient for this segment
        forward(size * 0.1) # Move out a bit from the center
        pendown()

        # Nested loop for concentric pattern within each segment
        # Halved iterations for faster drawing
        for j in range(int(size * 0.1)): # Cast to int
            pencolor(colors[(i + j) % len(colors)])
            current_width = max(1, int((size / 50) - (j / (size * 0.1) * (size / 50)) + 1)) # Ensure width is an integer
            width(current_width)
            forward(size * 0.05 + j * 0.005) # Gradually increase forward length
            left(10) # Small turn for a spiral within the petal
            forward(size * 0.05 + j * 0.005) # Another forward
            right(11) # Turn back slightly

        # Additional concentric layer / outline for the petal
        penup()
        setposition(x,y)
        setheading(initial_heading + i * segment_angle + segment_angle/2) # Move to middle of the segment
        forward(size * 0.15) # Start a bit out for the outline
        pendown()
        pencolor(colors[(i + 1) % len(colors)])
        width(max(1, int(size / 70))) # Ensure width is an integer
        # Halved iterations for faster drawing
        for k in range(int(size / 16)): # Cast to int
            forward(size * 0.003)
            right(2)
        for k in range(int(size / 16)): # Cast to int
            forward(size * 0.003)
            left(2)
        # --- Draw a 'petal' or segment --- END

        penup()
        setposition(x, y) # Return to center for the next segment
        pendown()
    showturtle() # Show turtle again after drawing the mandala

# Define vibrant colors for the mandala
mandala_colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#9400D3', '#FF1493', '#00FFFF']

# Draw the main intricate mandala in the center with reduced segments for faster drawing
draw_mandala(600, 450, 450, 18, mandala_colors)
# Out:
#       <svg width="1200" height="900">
#         <rect width="100%" height="100%" fill="black"/>
# ...
